# %%
#Importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Loading data
data = pd.read_csv('C:\\Users\\bhavi\\OneDrive\\Desktop\\Data\\Market_Basket_Optimisation.csv', header=None,
                   keep_default_na=False)

# %%
#Check the data
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs
# 2           chutney
# 3            turkey            avocado
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken
# 7499       escalope          green tea
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# 0     green grapes  whole weat flour  yams  cottage cheese  energy drink
# 1
# 2
# 3
# 4        green tea
# ...            ...               ...   ...             ...           ...
# 7496
# 7497     magazines         green tea
# 7498
# 7499
# 7500
# ...

# %%
transactions = []
for i in range(0,7501):
    transactions.append([str(data.values[i,j]) for j in range(0,20)]) #i for rows and j for columns

# %%
from association import eclat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-38b59aa379a6> in <module>
# ----> 1 from association import eclat
#
# ModuleNotFoundError: No module named 'association'

# %%
# !pip uninstall associations
# Out:
# ^C

# %%
from associations import
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-500656c5853f> in <module>
# ----> 1 from associations import eclat
#
# ImportError: cannot import name 'eclat' from 'associations' (c:\users\bhavi\appdata\local\programs\python\python38\lib\site-packages\associations\__init__.py)
